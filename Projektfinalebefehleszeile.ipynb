# %% [markdown]
# <a href="https://colab.research.google.com/github/Allen001822480/Info7374SpringTeam5/blob/Final_Project/Projektfinalebefehleszeile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Allen001822480/TAC-GAN.git
# Out:
# Cloning into 'TAC-GAN'...
# remote: Enumerating objects: 272, done.
# remote: Total 272 (delta 0), reused 0 (delta 0), pack-reused 272
# Receiving objects: 100% (272/272), 101.21 KiB | 8.43 MiB/s, done.
# Resolving deltas: 100% (158/158), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import zipfile
with zipfile.ZipFile('drive/My Drive/text_c10.zip','r') as zip_ref:
    zip_ref.extractall('TAC-GAN/Data/datasets/flowers')

# %%
import tarfile
with tarfile.TarFile('drive/My Drive/102flowers.tgz','r') as tar_ref:
  tar_ref.extractall('TAC-GAN/Data/datasets/flowers')

# %%
from distutils.dir_util import copy_tree
copy_tree("drive/My Drive/skipthoughts", "TAC-GAN/Data/skipthoughts")
# Out:
# ['TAC-GAN/Data/skipthoughts/bi_skip.npz.pkl',
#  'TAC-GAN/Data/skipthoughts/.DS_Store',
#  'TAC-GAN/Data/skipthoughts/uni_skip.npz.pkl',
#  'TAC-GAN/Data/skipthoughts/bi_skip.npz',
#  'TAC-GAN/Data/skipthoughts/btable.npy',
#  'TAC-GAN/Data/skipthoughts/uni_skip.npz',
#  'TAC-GAN/Data/skipthoughts/dictionary.txt',
#  'TAC-GAN/Data/skipthoughts/utable.npy']

# %%
import zipfile
with zipfile.ZipFile('drive/My Drive/processed_flowers.zip','r') as zip_ref:
    zip_ref.extractall('TAC-GAN/Data/datasets/flowers')

# %%
import os
os.chdir('TAC-GAN')

# %%
pwd
# Out:
# '/content/TAC-GAN'

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# !python dataprep.py --data_dir=Data --dataset=flowers
# Out:
# ['image_04809.jpg', 'image_00393.jpg', 'image_02109.jpg', 'image_01676.jpg', 'image_02035.jpg', 'image_04126.jpg', 'image_03620.jpg', 'image_06581.jpg', 'image_07442.jpg', 'image_05208.jpg', 'image_02247.jpg', 'image_04204.jpg', 'image_04625.jpg', 'image_06099.jpg', 'image_02872.jpg', 'image_03038.jpg', 'image_01345.jpg', 'image_02395.jpg', 'image_06139.jpg', 'image_03350.jpg', 'image_07372.jpg', 'image_06446.jpg', 'image_04007.jpg', 'image_08145.jpg', 'image_05184.jpg', 'image_06163.jpg', 'image_07246.jpg', 'image_05884.jpg', 'image_04665.jpg', 'image_06697.jpg', 'image_07251.jpg', 'image_01934.jpg', 'image_01871.jpg', 'image_08121.jpg', 'image_06537.jpg', 'image_04801.jpg', 'image_03366.jpg', 'image_07927.jpg', 'image_07965.jpg', 'image_03157.jpg', 'image_02545.jpg', 'image_02775.jpg', 'image_04001.jpg', 'image_02069.jpg', 'image_05168.jpg', 'image_00312.jpg', 'image_01258.jpg', 'image_03563.jpg', 'image_03892.jpg', 'image_04052.jpg', 'image_03821.jpg', 'image_06449.jpg', 'image_05
# ...

# %%
# !python train.py --t_dim=100 --image_size=128 --data_set=flowers --model_name=TAC_GAN --train=True --resume_model=True --z_dim=100 --n_classes=102 --epochs=30 --save_every=28 --caption_vector_length=4800 --batch_size=256
# Out:
# Initializing placeholder
# Building the Generator
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Building the Discriminator
# Building the Loss Function
# List of all variables
# g_embedding/Matrix:0
# <tf.Variable 'g_embedding/Matrix:0' shape=(4800, 100) dtype=float32_ref>
# g_embedding/bias:0
# <tf.Variable 'g_embedding/bias:0' shape=(100,) dtype=float32_ref>
# g_h0_lin/Matrix:0
# <tf.Variable 'g_h0_lin/Matrix:0' shape=(200, 32768) dtype=float32_ref>
# g_h0_lin/bias:0
# <tf.Variable 'g_h0_lin/bias:0' shape=(32768,) dtype=float32_ref>
# g_bn0/beta:0
# <tf.Variable 'g_bn0/beta:0' shape=(512,) dtype=float32_ref>
# g_h1/w:0
# <tf.Variable 'g_h1/w:0' shape=(5, 5, 256, 512) dtype=float32_ref>
# g_h1/biases:0
# ...

# %%
# !zip -r file.zip /content/TAC-GAN/Data/training/TAC_GAN
# Out:
#   adding: content/TAC-GAN/Data/training/TAC_GAN/ (stored 0%)
#   adding: content/TAC-GAN/Data/training/TAC_GAN/samples/ (stored 0%)
#   adding: content/TAC-GAN/Data/training/TAC_GAN/samples/fake_image_136.jpg (deflated 3%)
#   adding: content/TAC-GAN/Data/training/TAC_GAN/samples/66_image_01996.jpg.jpg (deflated 3%)
#   adding: content/TAC-GAN/Data/training/TAC_GAN/samples/fake_image_231.jpg (deflated 3%)
#   adding: content/TAC-GAN/Data/training/TAC_GAN/samples/fake_image_207.jpg (deflated 3%)
#   adding: content/TAC-GAN/Data/training/TAC_GAN/samples/41_image_08091.jpg.jpg (deflated 3%)
#   adding: content/TAC-GAN/Data/training/TAC_GAN/samples/34_image_03095.jpg.jpg (deflated 3%)
#   adding: content/TAC-GAN/Data/training/TAC_GAN/samples/76_image_04030.jpg.jpg (deflated 3%)
#   adding: content/TAC-GAN/Data/training/TAC_GAN/samples/145_image_01973.jpg.jpg (deflated 3%)
#   adding: content/TAC-GAN/Data/training/TAC_GAN/samples/27_image_05482.jpg.jpg (deflated 2%)
# ...

# %%
import os
os.listdir("/content/TAC-GAN/Data/training/TAC_GAN/checkpoints/29")
# Out:
# ['model_after_flowers_epoch_29.ckpt.data-00000-of-00001',
#  'model_after_flowers_epoch_29.ckpt.meta',
#  'checkpoint',
#  'model_after_flowers_epoch_29.ckpt.index']

# %%
# !zip -r /content/checkpoint29.zip /content/TAC-GAN/Data/training/TAC_GAN/checkpoints/29
# Out:
#   adding: content/TAC-GAN/Data/training/TAC_GAN/checkpoints/29/ (stored 0%)
#   adding: content/TAC-GAN/Data/training/TAC_GAN/checkpoints/29/model_after_flowers_epoch_29.ckpt.data-00000-of-00001 (deflated 8%)
#   adding: content/TAC-GAN/Data/training/TAC_GAN/checkpoints/29/model_after_flowers_epoch_29.ckpt.meta (deflated 90%)
#   adding: content/TAC-GAN/Data/training/TAC_GAN/checkpoints/29/checkpoint (deflated 89%)
#   adding: content/TAC-GAN/Data/training/TAC_GAN/checkpoints/29/model_after_flowers_epoch_29.ckpt.index (deflated 55%)

# %%
# !python encode_text.py --caption_file=Data/text.txt --data_dir=Data
# Out:
# Loading model parameters...
# Compiling encoders...
# WARNING (theano.tensor.blas): We did not find a dynamic library in the library_dir of the library we use for blas. If you use ATLAS, make sure to compile it with dynamics library.
# Loading tables...
# Packing up...
# ['a flower with red petals which are pointed', 'many pointed petals', 'A yellow flower']
# 8
# 3
# Finished extracting Skip-Thought vectors of the given text descriptions
# [303792419e3f:09280] *** Process received signal ***
# [303792419e3f:09280] Signal: Segmentation fault (11)
# [303792419e3f:09280] Signal code: Address not mapped (1)
# [303792419e3f:09280] Failing at address: 0x7f9c0d83d20d
# [303792419e3f:09280] [ 0] /lib/x86_64-linux-gnu/libpthread.so.0(+0x12890)[0x7f9c10af2890]
# [303792419e3f:09280] [ 1] /lib/x86_64-linux-gnu/libc.so.6(getenv+0xa5)[0x7f9c10731785]
# [303792419e3f:09280] [ 2] /usr/lib/x86_64-linux-gnu/libtcmalloc.so.4(_ZN13TCMallocGuardD1Ev+0x34)[0x7f9c10f9ce44]
# ...

# %%
# !python generate_images.py --data_set=flowers --t_dim=100 --image_size=128 --checkpoints_dir=Data/training/TAC_GAN/checkpoints --images_per_caption=30 --data_dir=Data
# Out:
# Initializing placeholder
# Building the Generator
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Building the Discriminator
# Building the Loss Function
# List of all variables
# g_embedding/Matrix:0
# <tf.Variable 'g_embedding/Matrix:0' shape=(4800, 100) dtype=float32_ref>
# g_embedding/bias:0
# <tf.Variable 'g_embedding/bias:0' shape=(100,) dtype=float32_ref>
# g_h0_lin/Matrix:0
# <tf.Variable 'g_h0_lin/Matrix:0' shape=(200, 32768) dtype=float32_ref>
# g_h0_lin/bias:0
# <tf.Variable 'g_h0_lin/bias:0' shape=(32768,) dtype=float32_ref>
# g_bn0/beta:0
# <tf.Variable 'g_bn0/beta:0' shape=(512,) dtype=float32_ref>
# g_h1/w:0
# <tf.Variable 'g_h1/w:0' shape=(5, 5, 256, 512) dtype=float32_ref>
# g_h1/biases:0
# ...

# %%
# !python train.py --t_dim=100 --image_size=128 --data_set=flowers --model_name=TAC_GAN --train=True --resume_model=True --z_dim=100 --n_classes=102 --epochs=40 --save_every=28 --caption_vector_length=4800 --batch_size=128
# Out:
# Initializing placeholder
# Building the Generator
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Building the Discriminator
# Building the Loss Function
# List of all variables
# g_embedding/Matrix:0
# <tf.Variable 'g_embedding/Matrix:0' shape=(4800, 100) dtype=float32_ref>
# g_embedding/bias:0
# <tf.Variable 'g_embedding/bias:0' shape=(100,) dtype=float32_ref>
# g_h0_lin/Matrix:0
# <tf.Variable 'g_h0_lin/Matrix:0' shape=(200, 32768) dtype=float32_ref>
# g_h0_lin/bias:0
# <tf.Variable 'g_h0_lin/bias:0' shape=(32768,) dtype=float32_ref>
# g_bn0/beta:0
# <tf.Variable 'g_bn0/beta:0' shape=(512,) dtype=float32_ref>
# g_h1/w:0
# <tf.Variable 'g_h1/w:0' shape=(5, 5, 256, 512) dtype=float32_ref>
# g_h1/biases:0
# ...

# %%
import shutil
shutil.rmtree('TAC-GAN/Data/skipthoughts')
